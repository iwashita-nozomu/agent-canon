# %% [markdown]
# # Experiment Visualization Template
#
# この notebook は `create_experiment_topic.py` が topic scaffold として配置します。
#
# ## Reader Map
#
# run artifact を読み、図表・軸・単位・readback を確認する visualization consumer です。
# 実験の algorithm、oracle、resource admission、failure classification を変更する場所ではありません。
#
# - what this notebook contains: result snapshot の読み込み、図表、表、解釈の補助。
# - source: `run_dir` 配下の immutable artifact。
# - validation: source artifact identity、formatter/readback、failure state の確認。
# - cleanup: executed notebook と図表は run retention owner の規則に従う。

# %% [markdown]
# ## Edit Targets
#
# `create_experiment_topic.py` が `experiments/<topic>/` に配置した後、次の順で編集します。
#
# 1. `run.py` `run_experiment()` and `run_case_worker()`
# 1. `cases.py`
# 1. `config.yaml`
# 1. `visualize.ipynb`
# 1. `README.md`
#
# C++ experiment/test は topic 内の単一 project に閉じ、top-level CMake は追加しません。

# %% [markdown]
# ## Run Context
#
# この code cell は `EXPERIMENT_RUN_DIR` から run directory を解決します。topic の artifact
# manifest、summary、cases、environment snapshot、failure evidence を読んでから visualization を追加します。
#
# IMPLEMENT HERE: add visualization cells that read artifacts from `run_dir` and render the topic-specific figures or tables.

# %%
from pathlib import Path
import os

run_dir = Path(os.environ["EXPERIMENT_RUN_DIR"]).resolve()
# IMPLEMENT HERE: summary.json、cases.jsonl、artifact-manifest.json、または topic artifact を読む。
# IMPLEMENT HERE: 軸名、単位、linear/log scale、source/result identity を read back する。
run_dir
