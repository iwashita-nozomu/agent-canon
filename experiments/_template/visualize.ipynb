# %% [markdown]
# # Experiment Visualization Template
#
# AgentCanon template path: `vendor/agent-canon/experiments/_template/`.

# %% [markdown]
# ## Edit Targets
#
# After copying this template to `experiments/<topic>/`, edit these files in order:
#
# 1. `run.py` `main::main`
# 1. `cases.py`
# 1. `config.yaml`
# 1. `visualize.ipynb`
# 1. `README.md`

# %% [markdown]
# ## Run Context
#
# This code cell resolves the run directory from `EXPERIMENT_RUN_DIR` and prepares the path used by visualization cells. Replace the placeholder once the topic writes concrete artifacts.

# %%
from pathlib import Path
import os

run_dir = Path(os.environ["EXPERIMENT_RUN_DIR"]).resolve()
run_dir
